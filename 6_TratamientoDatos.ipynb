# %% [markdown]
# # Tratamiento de Datos

# %% [markdown]
# ## Identificar Nulos

# %% [markdown]
# ### Conteo por Variable

# %%
import pandas as pd

# .isna = es nulo
df = pd.read_excel('/Users/jimenacambronero/Desktop/Proyectos para Portfolio/PythonPracticas/Datos/Frutos_Secos.xlsx', index_col='id', parse_dates=['Fecha Venta'])
df.isa()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/2d/p3zg32ds4p598pyxblpsp5ph0000gn/T/ipykernel_2676/1660468150.py in <module>
#       3 # .isna = es nulo
#       4 df = pd.read_excel('/Users/jimenacambronero/Desktop/Proyectos para Portfolio/PythonPracticas/Datos/Frutos_Secos.xlsx', index_col='id', parse_dates=['Fecha Venta'])
# ----> 5 df.isa()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'isa'

# %%
# conteo de nulos
df.isna().sum()
# Out:
# Nombre Cliente           0
# Tipo Producto            0
# Precio (€/kg)            0
# Cantidad Vendida (kg)    0
# Fecha Venta              0
# Provincia Cliente        0
# dtype: int64

# %%
#cargamos otro archivo con registros nulos
df_nulos= pd.read_csv('/Users/jimenacambronero/Desktop/Proyectos para Portfolio/PythonPracticas/Datos/registros_nulos.csv')
df_nulos
# Out:
#     ID    Nombre  Edad  Puntuacion
# 0    1   Nombre1   NaN        95.0
# 1    2   Nombre2  25.0         NaN
# 2    3   Nombre3   NaN         NaN
# 3    4   Nombre4  30.0         NaN
# 4    5   Nombre5  25.0         NaN
# 5    6   Nombre6   NaN        90.0
# 6    7   Nombre7  30.0        95.0
# 7    8   Nombre8  30.0         NaN
# 8    9   Nombre9   NaN        95.0
# 9   10  Nombre10  25.0        90.0
# 10  11  Nombre11  30.0        90.0
# 11  12  Nombre12  25.0        90.0
# 12  13  Nombre13  30.0        95.0
# 13  14  Nombre14  30.0        90.0
# 14  15  Nombre15  30.0        90.0
# 15  16  Nombre16   NaN        95.0
# 16  17  Nombre17   NaN         NaN
# 17  18  Nombre18  30.0         NaN
# 18  19  Nombre19  25.0         NaN
# 19  20  Nombre20  25.0        90.0
# 20  21  Nombre21  25.0         NaN
# 21  22  Nombre22   NaN        95.0
# 22  23  Nombre23  30.0        90.0
# 23  24  Nombre24   NaN        95.0
# 24  25  Nombre25  30.0         NaN
# 25  26  Nombre26   NaN         NaN
# ...

# %%
df_nulos.isna().sum()
# Out:
# ID             0
# Nombre         0
# Edad          15
# Puntuacion    20
# dtype: int64

# %%
df_nulos.isna().sum().sort_values(ascending=False)
# Out:
# Puntuacion    20
# Edad          15
# ID             0
# Nombre         0
# dtype: int64

# %% [markdown]
# ### Porcentaje por Variable

# %%
df_nulos.isna().mean().sort_values(ascending= False)*100
#obtendremos el porcentaje de nulos
# Out:
# Puntuacion    40.0
# Edad          30.0
# ID             0.0
# Nombre         0.0
# dtype: float64

# %% [markdown]
# ## Conteo de Duplicados

# %%
df_duplicados= pd.read_excel('/Users/jimenacambronero/Desktop/Proyectos para Portfolio/PythonPracticas/Datos/Frutos_Secos_duplicados.xlsx')

# %%
#Saber cuantos duplicados hay
df_duplicados.duplicated().sum()
# Out:
# 23

# %% [markdown]
# ### Localizar Duplicados

# %%
df_duplicados[df_duplicados.duplicated()]
# Out:
#     Nombre Cliente Tipo Producto  Precio (€/kg)  Cantidad Vendida (kg)  \
# 300        Caprabo    Cacahuetes           6.24                   1626
# 301        Caprabo    Cacahuetes           6.24                   1626
# 302        Caprabo    Cacahuetes           6.24                   1626
# 303        Caprabo    Cacahuetes           6.24                   1626
# 304        Caprabo    Cacahuetes           6.24                   1626
# 305        Caprabo    Cacahuetes           6.24                   1626
# 306        Caprabo    Cacahuetes           6.24                   1626
# 307        Caprabo    Cacahuetes           6.24                   1626
# 308        Caprabo    Cacahuetes           6.24                   1626
# 309        Caprabo    Cacahuetes           6.24                   1626
# 310        Caprabo    Cacahuetes           6.24                   1626
# 311        Caprabo    Cacahuetes           6.24                   1626
# ...

# %%
# Ver duplicados de otra manera
df_duplicados[df_duplicados.duplicated(keep=False)]
# Out:
#     Nombre Cliente Tipo Producto  Precio (€/kg)  Cantidad Vendida (kg)  \
# 23         Caprabo    Cacahuetes           6.24                   1626
# 300        Caprabo    Cacahuetes           6.24                   1626
# 301        Caprabo    Cacahuetes           6.24                   1626
# 302        Caprabo    Cacahuetes           6.24                   1626
# 303        Caprabo    Cacahuetes           6.24                   1626
# 304        Caprabo    Cacahuetes           6.24                   1626
# 305        Caprabo    Cacahuetes           6.24                   1626
# 306        Caprabo    Cacahuetes           6.24                   1626
# 307        Caprabo    Cacahuetes           6.24                   1626
# 308        Caprabo    Cacahuetes           6.24                   1626
# 309        Caprabo    Cacahuetes           6.24                   1626
# 310        Caprabo    Cacahuetes           6.24                   1626
# ...

# %% [markdown]
# ## Análisis de Valores Únicos
# Si una variable solo tiene un valor no te aporta nada en tu análisis

# %% [markdown]
# ### Número e Valores Únicos

# %%
df = pd.read_excel('/Users/jimenacambronero/Desktop/Proyectos para Portfolio/PythonPracticas/Datos/Frutos_Secos_unicos.xlsx')

# %%
df.nunique()
# Out:
# Nombre Cliente            11
# Tipo Producto              4
# Precio (€/kg)            258
# Cantidad Vendida (kg)    284
# Fecha Venta              204
# Provincia Cliente          6
# id                       300
# Completado                 1
# dtype: int64

# %%
 # puede eliminarse porque es una constante
# Out:
# 0      Si
# 1      Si
# 2      Si
# 3      Si
# 4      Si
#        ..
# 295    Si
# 296    Si
# 297    Si
# 298    Si
# 299    Si
# Name: Completado, Length: 300, dtype: object

# %% [markdown]
# ### Valores Únicos Diferentes

# %%
df['Provincia Cliente'].unique()
# Out:
# array(['Cádiz', 'Sevilla', 'Madrid', 'Alicante', 'Barcelona', 'Valencia'],
#       dtype=object)
